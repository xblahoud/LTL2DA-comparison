# %% [markdown]
# # Spot complete problem
# During transformation from tr.-based to st.-based acceptance, Spot gets trapped by its own checks, I assume.

# %%
f = 'G(F(((p0) & ((p0) R (F(p1))) & (F(((p2) & (X(p0))) | ((!(p2)) & (X(!(p0))))))) | (((!(p0)) U (G(!(p1)))) & ((!(p0)) | (G(((p2) & (X(!(p0)))) | ((!(p2)) & (X(p0)))))))))'

# %%
# !../Rab4/bin/ltl2dra '{f}' | autfilt
# Out:
# Dec 22, 2017 1:55:02 PM owl.run.PipelineRunner$TransformerExecution lambda$call$0
# INFO: Meta information for G(F(p0 & ((p0) R (Fp1)) & (F(p2 & Xp0) | F(!p2 & X!p0))) | F(((!p0) U (G!p1)) & (!p0 | G((p2 & X!p0) | (!p2 & Xp0))))):
# Execution of transformers took 0.85 sec
# HOA: v1
# States: 81
# Start: 0
# AP: 3 "p0" "p1" "p2"
# acc-name: Rabin 5
# Acceptance: 10 (Fin(0) & Inf(1)) | (Fin(2) & Inf(3)) | (Fin(4) & Inf(5)) | (Fin(6) & Inf(7)) | (Fin(8) & Inf(9))
# properties: trans-labels explicit-labels trans-acc deterministic
# --BODY--
# State: 0
# [0&!1&!2] 48 {9}
# [0&!1&2] 49 {9}
# [0&1&2] 40 {3 8}
# [0&1&!2] 45 {3 8}
# [!0] 32
# State: 1
# [0&!1&2] 2 {9}
# [0&!1&!2] 1 {9}
# [0&1&2] 3 {4 6 8}
# [0&1&!2] 4 {4 6 8}
# [!0&1] 5 {1 3 5 6 8}
# [!0&!1] 6 {1 7 8}
# State: 2
# [!0&1&2] 3 {4 6 8}
# [0&1&!2] 61 {1 3 5 6 8}
# [!0&1&!2] 4 {4 6 8}
# [0&1&2] 62 {1 3 5 6 8}
# [!0&!1&!2] 1 {7 9}
# [!0&!1&2] 2 {7 9}
# [0&!1&!2] 18 {1 8}
# [0&!1&2] 51 {1 8}
# State: 3
# [0&1&!2] 61 {1 3 6 8}
# ...

# %%
# !../Rab4/bin/ltl2dra '{f}' | autfilt -S
# Out:
# Dec 22, 2017 1:55:03 PM owl.run.PipelineRunner$TransformerExecution lambda$call$0
# INFO: Meta information for G(F(p0 & ((p0) R (Fp1)) & (F(p2 & Xp0) | F(!p2 & X!p0))) | F(((!p0) U (G!p1)) & (!p0 | G((p2 & X!p0) | (!p2 & Xp0))))):
# Execution of transformers took 0.81 sec
# autfilt: print_hoa(): automaton is complete but prop_complete()==false
