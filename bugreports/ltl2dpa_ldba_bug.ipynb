# %%
import spot
spot.setup(show_default='.a')

# %%
f = 'G!a | ((!a U b) W a)'
spot.formula(f)
# Out:
# G!a | ((!a U b) W a)

# %%
a = spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '"+f+"' |"); a
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f0a583bc630> >

# %% [markdown]
# Clearly, this automaton does not accept $(\emptyset\{b\})^\omega \in \mathsf{G}\neg a$.

# %%
a = spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '"+f+"' |"); a
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f0a583bc540> >

# %%
a = spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '"+f+"' |"); a
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f0a583bce70> >

# %%
a = spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '"+f+"' |"); a
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f0a583bce40> >

# %%
a = spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '"+f+"' |"); a
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f0a583bce10> >
