# %% [markdown]
# # Ltlcross
# There is a bug in ltlcross.

# %%
import spot
spot.setup(show_default='.a')

# %%
f = '(p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0))))))))'
spot.formula(f)
# Out:
# p0 & GF((p0 | p1) & (Gp0 | FG!p0))

# %%
# !ltlcross -t ltl2tgba -t "../Rab4/bin/ltl2dra  %f > %O" -t "../Rab4/bin/ltl2dgra  %f > %O" -f '{f}'
# Out:
# (p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0))))))))
# Running [P0]: ltl2tgba -H '(p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0))))))))'>'lcr-o0-qb6lGK'
# Running [P1]: ../Rab4/bin/ltl2dra  '(p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0))))))))' > 'lcr-o1-rb4EZe'
# Running [P2]: ../Rab4/bin/ltl2dgra  '(p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0))))))))' > 'lcr-o2-dCoybM'
# Running [N0]: ltl2tgba -H '!((p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0)))))))))'>'lcr-o0-HuMgyl'
# Running [N1]: ../Rab4/bin/ltl2dra  '!((p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0)))))))))' > 'lcr-o1-G4sWXU'
# Running [N2]: ../Rab4/bin/ltl2dgra  '!((p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0)))))))))' > 'lcr-o2-CMkxMw'
# Performing sanity checks and gathering statistics...
# error: P1*N0 is nonempty; both automata accept the infinite word:
#        p0; cycle{!p0 & !p1}
# error: P1*N1 is nonempty; both automata accept the infinite word:
#        p0; cycle{!p0 & !p1}
# ...

# %%
p = spot.automaton('../Rab4/bin/ltl2dra "{}" |'.format(f)); p
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7efd84541ba0> >

# %%
n0 = spot.automaton("ltl2tgba -H '!((p0) & (G(F(((p0) | (p1)) & ((G(p0)) | (F(G(!(p0)))))))))' |")
prod = spot.product(p,n0)
prod.postprocess()
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7efd845cb150> >
