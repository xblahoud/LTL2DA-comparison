# %% [markdown]
# # ltl2dpa(ldba) bug
# version from 22nd Jan 2018

# %%
import spot
spot.setup(show_default='.a')

# %%
spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba 'F((p0) & (((p0) & (G((p1) U (p2)))) | ((!(p0)) & (F((!(p1)) R (!(p2)))))))' |")
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fa674149120> >

# %%
spot.automaton("../Rab4/bin/ltl2dpa --mode=ldba '!(F((p0) & (((p0) & (G((p1) U (p2)))) | ((!(p0)) & (F((!(p1)) R (!(p2))))))))' |")
# Out:
# <spot.impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fa6741492d0> >

# %% [markdown]
# Both automata reject $\{p_0,p_1\}^\omega$
